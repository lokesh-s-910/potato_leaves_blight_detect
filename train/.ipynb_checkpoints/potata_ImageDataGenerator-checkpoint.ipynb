# %%
import numpy as np
import keras
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import HTML 
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array
import warnings
warnings.filterwarnings('ignore')
from tensorflow.keras import models, layers

# %%
train_gen = ImageDataGenerator(rescale=1./255, rotation_range=10, horizontal_flip=True)
train_generator = train_gen.flow_from_directory("dataset/train", target_size=(256,256), batch_size=32, class_mode='sparse', save_to_dir='augmentedimages')
# Out:
# Found 1506 images belonging to 3 classes.

# %%
validation = ImageDataGenerator(rescale=1./255, rotation_range=10, horizontal_flip=True)
validation_gen = validation.flow_from_directory("dataset/val", target_size=(256,256), batch_size=32, class_mode='sparse')
# Out:
# Found 215 images belonging to 3 classes.

# %%
test= ImageDataGenerator(rescale=1./255, rotation_range=10, horizontal_flip=True)
test_gen = test.flow_from_directory("dataset/test", target_size=(256,256), batch_size=32, class_mode='sparse')
# Out:
# Found 431 images belonging to 3 classes.

# %%
model = models.Sequential([
    layers.InputLayer(input_shape=(256,256,3)),
    layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu'),
    layers.MaxPool2D(pool_size=(2,2)),
    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.MaxPool2D(pool_size=(2,2)),
    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.MaxPool2D(pool_size=(2,2)),
    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.MaxPool2D(pool_size=(2,2)),
    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.MaxPool2D(pool_size=(2,2)),
    layers.Flatten(),
    layers.Dense(units=64, activation='relu'),
    layers.Dense(units=3, activation='softmax')
])

model.compile(optimizer='adam', loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False), metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Arvind\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model_earlystop = EarlyStopping(monitor='val_accuracy',
                                verbose=1,
                                min_delta=0.01,
                                patience=5,
                                mode='auto')

model_history = model.fit(train_generator, 
                          steps_per_epoch=47, 
                          batch_size=32, 
                          validation_data=validation_gen, 
                          validation_steps=6,
                          verbose=1,
                          epochs=20,
                          callbacks=model_earlystop)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\Arvind\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Arvind\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 47/47 [==============================] - 290s 6s/step - loss: 0.9377 - accuracy: 0.4552 - val_loss: 0.8755 - val_accuracy: 0.4688
# Epoch 2/20
# 47/47 [==============================] - 337s 7s/step - loss: 0.7391 - accuracy: 0.6513 - val_loss: 0.5959 - val_accuracy: 0.7812
# Epoch 3/20
# 47/47 [==============================] - 333s 7s/step - loss: 0.3791 - accuracy: 0.8480 - val_loss: 0.3521 - val_accuracy: 0.8490
# Epoch 4/20
# 47/47 [==============================] - 323s 7s/step - loss: 0.2676 - accuracy: 0.8894 - val_loss: 0.2678 - val_accuracy: 0.8906
# Epoch 5/20
# 47/47 [==============================] - 307s 7s/step - loss: 0.2437 - accuracy: 0.9043 - val_loss: 0.2072 - val_accuracy: 0.9271
# Epoch 6/20
# 47/47 [==============================] - 301s 6s/step - loss: 0.2050 - accuracy: 0.9220 - val_loss: 0.3498 - val_accuracy: 0.8385
# Epoch 7/20
# 47/47 [==============================] - 235s 5s/step - loss: 0.2283 - accuracy: 0.9159 - val_loss: 0.2598 - val_accuracy: 0.8802
# Epoch 8/20
# 47/47 [==============================] - 308s 7s/step - loss: 0.1449 - accuracy: 0.9464 - val_loss: 0.1055 - val_accuracy: 0.9688
# Epoch 9/20
# 47/47 [==============================] - 305s 6s/step - loss: 0.1525 - accuracy: 0.9423 - val_loss: 0.1454 - val_accuracy: 0.9531
# Epoch 10/20
# 47/47 [==============================] - 302s 6s/step - loss: 0.1701 - accuracy: 0.9342 - val_loss: 0.1382 - val_accuracy: 0.9531
# Epoch 11/20
# 47/47 [==============================] - 229s 5s/step - loss: 0.1408 - accuracy: 0.9481 - val_loss: 0.1148 - val_accuracy: 0.9531
# Epoch 12/20
# 47/47 [==============================] - 213s 4s/step - loss: 0.1079 - accuracy: 0.9613 - val_loss: 0.1018 - val_accuracy: 0.9531
# Epoch 13/20
# 47/47 [==============================] - 204s 4s/step - loss: 0.1081 - accuracy: 0.9627 - val_loss: 0.0904 - val_accuracy: 0.9583
# Epoch 14/20
# 47/47 [==============================] - 307s 6s/step - loss: 0.1065 - accuracy: 0.9600 - val_loss: 0.0722 - val_accuracy: 0.9844
# Epoch 15/20
# 47/47 [==============================] - 306s 6s/step - loss: 0.0896 - accuracy: 0.9688 - val_loss: 0.0741 - val_accuracy: 0.9740
# Epoch 16/20
# 47/47 [==============================] - 301s 6s/step - loss: 0.0771 - accuracy: 0.9715 - val_loss: 0.0924 - val_accuracy: 0.9740
# Epoch 17/20
# 47/47 [==============================] - 235s 5s/step - loss: 0.0753 - accuracy: 0.9722 - val_loss: 0.0823 - val_accuracy: 0.9740
# Epoch 18/20
# 47/47 [==============================] - 284s 6s/step - loss: 0.0773 - accuracy: 0.9749 - val_loss: 0.0855 - val_accuracy: 0.9688
# Epoch 19/20
# 47/47 [==============================] - 304s 6s/step - loss: 0.0622 - accuracy: 0.9756 - val_loss: 0.0600 - val_accuracy: 0.9792
# Epoch 20/20
# 47/47 [==============================] - 307s 6s/step - loss: 0.0816 - accuracy: 0.9681 - val_loss: 0.0837 - val_accuracy: 0.9635

# %%
score = model.evaluate(test_gen)
# Out:
# 14/14 [==============================] - 27s 2s/step - loss: 0.0893 - accuracy: 0.9652

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(model_history.history['accuracy'], label='accuracy')
plt.plot(model_history.history['val_accuracy'], label='val_accuracy')
plt.title("Accuracy VS Val_Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1,2,2)
plt.plot(model_history.history['loss'], label='loss')
plt.plot(model_history.history['val_loss'], label='val_loss')
plt.title("Loss VS Val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
class_names = list(train_generator.class_indices.keys())
def predict(model,img):
    img_array = img_to_array(images[i])
    img_array = tf.expand_dims(img_array, axis=0)
    predictions = model.predict(img_array)
    predict_class = class_names[np.argmax(predictions[0])]
    confidence = round(100*(np.max(predictions[0])),2)
    return predict_class, confidence

# %%
plt.figure(figsize=(15,15))
for images, labels in test_gen:
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(images[i])
        predict_class, confidence = predict(model, images[i])
        actual_class = class_names[int(labels[i])]
        plt.title("Actual_Label: {0},\n Predicted_Label: {1},\n Confidence: {2}%".format(actual_class, predict_class, confidence))
        plt.axis('off')
    break
plt.show()

# %%
model.save("../potato.h5")
